# %%
import pandas as pd
import numpy as np
import datetime

# %%
df_sales = pd.read_csv("./data/item_sales.csv")

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1920 entries, id to d_1913
# dtypes: int64(1913), object(7)
# memory usage: 446.6+ MB

# %%
df_sales.drop_duplicates(inplace=True)

# %%
df_sales.isnull().sum()
# Out:
# id            0
# item          0
# category      0
# department    0
# store         0
#              ..
# d_1909        0
# d_1910        0
# d_1911        0
# d_1912        0
# d_1913        0
# Length: 1920, dtype: int64

# %%
print(df_sales.shape)
df_sales.head(1)
# Out:
# (30490, 1920)
#                        id              item    category    department  \
# 0  ACCESORIES_1_001_NYC_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
#
#                store store_code    region  d_1  d_2  d_3  ...  d_1904  d_1905  \
# 0  Greenwich_Village      NYC_1  New York    0    0    0  ...       1       3
#
#    d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 0       0       1       1       1       3       0       1       1
#
# [1 rows x 1920 columns]

# %%
start_date = '2011-01-29'
end_date = '2016-04-24'

# %%
date_range = pd.date_range(start=start_date, end= end_date, freq='D')
date_range = date_range.to_list()
columns_new = df_sales.columns[:7].to_list()
columns_for_rename = columns_new + date_range

df_sales.columns = columns_for_rename

# %%
df_sales.head(1)
# Out:
#                        id              item    category    department  \
# 0  ACCESORIES_1_001_NYC_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
#
#                store store_code    region  2011-01-29 00:00:00  \
# 0  Greenwich_Village      NYC_1  New York                    0
#
#    2011-01-30 00:00:00  2011-01-31 00:00:00  ...  2016-04-15 00:00:00  \
# 0                    0                    0  ...                    1
#
#    2016-04-16 00:00:00  2016-04-17 00:00:00  2016-04-18 00:00:00  \
# 0                    3                    0                    1
#
#    2016-04-19 00:00:00  2016-04-20 00:00:00  2016-04-21 00:00:00  \
# 0                    1                    1                    3
#
#    2016-04-22 00:00:00  2016-04-23 00:00:00  2016-04-24 00:00:00
# 0                    0                    1                    1
#
# [1 rows x 1920 columns]

# %%
first_columns = df_sales.iloc[:, :7]
date_columns = [col for col in df_sales.columns[7:].to_list()]
df_sales_melted = df_sales.melt(id_vars=first_columns.columns.tolist(), value_vars=date_columns, var_name='date', value_name='sales')

# %%
df_sales_melted
# Out:
#                                id               item     category  \
# 0          ACCESORIES_1_001_NYC_1   ACCESORIES_1_001   ACCESORIES
# 1          ACCESORIES_1_002_NYC_1   ACCESORIES_1_002   ACCESORIES
# 2          ACCESORIES_1_003_NYC_1   ACCESORIES_1_003   ACCESORIES
# 3          ACCESORIES_1_004_NYC_1   ACCESORIES_1_004   ACCESORIES
# 4          ACCESORIES_1_005_NYC_1   ACCESORIES_1_005   ACCESORIES
# ...                           ...                ...          ...
# 58327365  SUPERMARKET_3_823_PHI_3  SUPERMARKET_3_823  SUPERMARKET
# 58327366  SUPERMARKET_3_824_PHI_3  SUPERMARKET_3_824  SUPERMARKET
# 58327367  SUPERMARKET_3_825_PHI_3  SUPERMARKET_3_825  SUPERMARKET
# 58327368  SUPERMARKET_3_826_PHI_3  SUPERMARKET_3_826  SUPERMARKET
# 58327369  SUPERMARKET_3_827_PHI_3  SUPERMARKET_3_827  SUPERMARKET
#
#              department              store store_code        region  \
# 0          ACCESORIES_1  Greenwich_Village      NYC_1      New York
# 1          ACCESORIES_1  Greenwich_Village      NYC_1      New York
# 2          ACCESORIES_1  Greenwich_Village      NYC_1      New York
# 3          ACCESORIES_1  Greenwich_Village      NYC_1      New York
# 4          ACCESORIES_1  Greenwich_Village      NYC_1      New York
# ...                 ...                ...        ...           ...
# 58327365  SUPERMARKET_3      Queen_Village      PHI_3  Philadelphia
# 58327366  SUPERMARKET_3      Queen_Village      PHI_3  Philadelphia
# 58327367  SUPERMARKET_3      Queen_Village      PHI_3  Philadelphia
# 58327368  SUPERMARKET_3      Queen_Village      PHI_3  Philadelphia
# 58327369  SUPERMARKET_3      Queen_Village      PHI_3  Philadelphia
#
#                          date  sales
# 0         2011-01-29 00:00:00      0
# 1         2011-01-29 00:00:00      0
# 2         2011-01-29 00:00:00      0
# 3         2011-01-29 00:00:00      0
# 4         2011-01-29 00:00:00      0
# ...                       ...    ...
# 58327365  2016-04-24 00:00:00      1
# 58327366  2016-04-24 00:00:00      0
# 58327367  2016-04-24 00:00:00      0
# 58327368  2016-04-24 00:00:00      3
# 58327369  2016-04-24 00:00:00      0
#
# [58327370 rows x 9 columns]

# %%
df_sales_melted.drop(columns=["item", "category", "department", "store_code", "region"], axis=1, inplace=True)

# %%
df_sales_melted
# Out:
#                                id              store                 date  \
# 0          ACCESORIES_1_001_NYC_1  Greenwich_Village  2011-01-29 00:00:00
# 1          ACCESORIES_1_002_NYC_1  Greenwich_Village  2011-01-29 00:00:00
# 2          ACCESORIES_1_003_NYC_1  Greenwich_Village  2011-01-29 00:00:00
# 3          ACCESORIES_1_004_NYC_1  Greenwich_Village  2011-01-29 00:00:00
# 4          ACCESORIES_1_005_NYC_1  Greenwich_Village  2011-01-29 00:00:00
# ...                           ...                ...                  ...
# 58327365  SUPERMARKET_3_823_PHI_3      Queen_Village  2016-04-24 00:00:00
# 58327366  SUPERMARKET_3_824_PHI_3      Queen_Village  2016-04-24 00:00:00
# 58327367  SUPERMARKET_3_825_PHI_3      Queen_Village  2016-04-24 00:00:00
# 58327368  SUPERMARKET_3_826_PHI_3      Queen_Village  2016-04-24 00:00:00
# 58327369  SUPERMARKET_3_827_PHI_3      Queen_Village  2016-04-24 00:00:00
#
#           sales
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 58327365      1
# 58327366      0
# 58327367      0
# 58327368      3
# 58327369      0
#
# [58327370 rows x 4 columns]

# %%
df_sales_melted["date"] = pd.to_datetime(df_sales_melted["date"])

# %%
df_sales_melted.set_index("date", inplace=True)

# %%
df_sales_resampled = df_sales_melted.groupby("id")["sales"].resample("M").sum().reset_index()
# Out:
# C:\Users\rafas\AppData\Local\Temp\ipykernel_8816\1716618031.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_sales_resampled = df_sales_melted.groupby("id")["sales"].resample("M").sum().reset_index()

# %%
df_sales_resampled
# Out:
#                               id       date  sales
# 0         ACCESORIES_1_001_BOS_1 2011-01-31      0
# 1         ACCESORIES_1_001_BOS_1 2011-02-28      0
# 2         ACCESORIES_1_001_BOS_1 2011-03-31      0
# 3         ACCESORIES_1_001_BOS_1 2011-04-30      0
# 4         ACCESORIES_1_001_BOS_1 2011-05-31      0
# ...                          ...        ...    ...
# 1951355  SUPERMARKET_3_827_PHI_3 2015-12-31     41
# 1951356  SUPERMARKET_3_827_PHI_3 2016-01-31     49
# 1951357  SUPERMARKET_3_827_PHI_3 2016-02-29     46
# 1951358  SUPERMARKET_3_827_PHI_3 2016-03-31     68
# 1951359  SUPERMARKET_3_827_PHI_3 2016-04-30     15
#
# [1951360 rows x 3 columns]

# %%
df_sales_melted

# %%
df_sales_resample = df_sales_melted.resample('W', on='date').sum()

# %%
file_name = "df_sales_clean_resampled.csv"
df_sales_resampled.to_csv(file_name)
